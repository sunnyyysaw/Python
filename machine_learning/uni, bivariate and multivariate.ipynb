# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Univariate Analysis

# %%
setosa = df.loc[df['species'] == 'setosa']
virgin = df.loc[df['species'] == 'virginica']
vergi = df.loc[df['species'] == 'versicolor']

# %%
plt.plot(setosa['sepal_length'], np.zeros_like(setosa['sepal_length']))
plt.plot(virgin['sepal_length'], np.zeros_like(virgin['sepal_length']))
plt.plot(vergi['sepal_length'], np.zeros_like(vergi['sepal_length']))
plt.xlabel('Sepal Length')
# Out:
# Text(0.5, 0, 'Sepal Length')

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.FacetGrid(df, hue = 'species').map(plt.scatter, 'petal_length', 'sepal_width').add_legend()

# %% [markdown]
# ## Multivariate Analysis

# %%
sns.pairplot(df, hue = 'species', size = 3)
# Out:
# C:\Users\Sunny\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
